# %%
import pandas as pd
from sklearn.datasets import load_iris
iris=load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
# %matplotlib inline
pd.plotting.scatter_matrix(data[iris.feature_names], figsize=(10, 10), c=data['target'], marker='o',
                           hist_kwds={'bins': 20}, s=60, alpha=0.8, cmap='viridis')
plt.suptitle("Scatter Matrix of Iris Dataset")
plt.show()

# %%
df=pd.DataFrame(iris.data)
df.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
df['target']=iris.target
df.head()
# Out:
#      0    1    2    3  target
# 0  5.1  3.5  1.4  0.2       0
# 1  4.9  3.0  1.4  0.2       0
# 2  4.7  3.2  1.3  0.2       0
# 3  4.6  3.1  1.5  0.2       0
# 4  5.0  3.6  1.4  0.2       0

# %% [markdown]
# # TRAIN_TEST_SPLIT THE MODEL

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(['target'],axis='columns'),iris.target,test_size=0.2)

# %% [markdown]
# # SELECT THE MODEL FOR RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=10)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
model.score(X_test,y_test)
# Out:
# 0.9666666666666667

# %%
y_pradicted=model.predict(X_test)

# %% [markdown]
# # IMPORT CONFUSION METRIX

# %% [markdown]
# from sklearn.metrics import confusion_matrix
# cm=confusion_matrix(y_test,y_pradicted)
# cm

# %%
 # %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')
